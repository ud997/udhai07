# %%
import pandas as pd

# %%
import os

# %%
File=pd.read_excel("data.xlsx",sheet_name=None)
#df_sheet_all = pd.read_excel('sample.xlsx', sheet_name=None)#
#print(df_sheet_all)
File1=pd.read_excel("data_1.xlsx",sheet_name=None)

# %%
File
# Out:
# {'Info':                                  Testing Information       Unnamed: 1  \
#  0                          240067-1-1-2818574209.xls              NaN
#  1                                2020-10-16 08:34:59              NaN
#  2  C:\Users\shivangi\Desktop\1522\xls\240067-1-1-...              NaN
#  3                            Cycle Mode:Charge First              NaN
#  4                                      Process Name:  Cap-2900mAh.xml
#  5                                          Equipment             Unit
#  6                                                 67                1
#
#    Unnamed: 2              Unnamed: 3    Unnamed: 4           Unnamed: 5  \
#  0        NaN                     NaN           NaN                  NaN
#  1        NaN                     NaN           NaN                  NaN
#  2        NaN                     NaN           NaN                  NaN
#  3        NaN                     NaN           NaN                  NaN
# ...

# %%
File1.keys()
# Out:
# dict_keys(['DetailTemp_67_1_1_3', 'DetailTemp_67_1_1_4', 'DetailTemp_67_1_1_5', 'DetailTemp_67_1_1_6'])

# %%
# for k,v in File:
#     if File[k]==Detail_67:
#         print(File[Detail_67])
# for field, possible_values in File:
#     print(field.keys())
li=[]
dataframes=[]
dataframes1=[]
dataframes2=[]
keys = File.keys()
for i in keys:
  li.append(i)
for i in li:
    if 'Detail_67' in i:
        dataframes.append(File[i])
    if 'DetailVol_67_' in i:
        dataframes1.append(File[i])
    if 'DetailTemp_67_' in i:
        dataframes2.append(File[i])
join=pd.concat(dataframes)
join.to_csv('detail.csv')
join1=pd.concat(dataframes1)
join1.to_csv('detailVol.csv')
# join1=pd.concat(dataframes2)
# join1.to_csv('detailTemp.csv')

# %%
li1=[]
# dataframes=[]
# dataframes1=[]
# dataframes2=[]
keys1= File1.keys()
for i in keys1:
  li1.append(i)
for i in li1:
#     if 'Detail_67' in i:
#         dataframes.append(File[i])
#     if 'DetailVol_67_' in i:
#         dataframes1.append(File[i])
    if 'DetailTemp_67_' in i:
        dataframes2.append(File1[i])
# join=pd.concat(dataframes)
# join.to_csv('detail.csv')
# join1=pd.concat(dataframes1)
# join1.to_csv('detailVol.csv')
join1=pd.concat(dataframes2)
join1.to_csv('detailTemp.csv')
